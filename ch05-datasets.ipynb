# %% [markdown]
# ### <b style="color: #abcdef">05.비전 데이터셋 만들기</b>

# %% [markdown]
# > #### <b style="color: #58a491">이미지 수집</b>
# > - 예산으로 감당할 수 있는 선에서 최고 해상도 사용
# > - 저해상도 장점: 빠르다, 빠르다, 빠르다, 빠르다, 빠르다
# > - 대상의 형태가 유지될 만큼의 해상도가 필요
# > - 도면은 비압축이 좋다

# %% [markdown]
# > #### <b style="color: #f86461">이미징</b>
# > ---
# > <b style="color: #53a593">극격자</b>
# > - 원본 이미지에 픽셀 거리 추가하여 사용하는게 좋다.
# > - 그러니까... 선형 레이어에 넣기 전에 보완데이터를 넣어주는게 좋다
# > ---
# > <b style="color: #53a593">위성채널</b>
# > - 무슨 말을 해도 못알아먹게 써놔 ㅅㅂ
# > - 6채널이니까 사전학습된 모델 사용 불가
# > - 처음부터 훈련해야 함
# > ---
# > <b style="color: #53a593">지리공간레이어</b>
# > - 당최 뭔소린지...

# %% [markdown]
# > #### <b style="color: #f86461">개념증명</b>
# > - 데이터가 없으면 유사한 이미지 구입 고려
# > - 이미지 품질, 해상도가 실제로 구할 수 있는 이미지와 유사해야 함
# > - 이미지 시뮬레이션??

# %% [markdown]
# > #### <b style="color: #f86461">데이터타입</b>
# > ---
# > <b style="color: #53a593">채널</b>
# > - RGB, RGBA. 일반적으로 A는 무시
# > - channel_first가 효율이 좋지만 편의가 중시되어 channel_last가 기본값
# > - 각 픽셀의 값은 0, 1 사이값으로 스케일링
# > - 회색조는 2D 데이터일 수 있으므로 axis 추가 필요할수 있다
# > ---
# > <b style="color: #53a593">회색조</b>
# > - 무슨 말을 해도 못알아먹게 써놔 ㅅㅂ
# > - 6채널이니까 사전학습된 모델 사용 불가
# > - 처음부터 훈련해야 함
# > ---
# > <b style="color: #53a593">지리공간레이어</b>
# > - 강이나 도로같은 구분되는 영역은 레스터화를...
# > ---
# > <b style="color: #53a593">어쩌고 저쩌고 blar blar blar</b>

# %% [markdown]
# > #### <b style="color: #f86461">라벨링</b>
# > ---
# > <b style="color: #53a593">수동 라벨링</b>
# > - 폴더로 구분
# > - 메타데이터로 관리(csv 등)
# > - 다중레벨은 메타데이터로...
# > - 객체검출은 메타데이터로...
# > - 세분화는 메타데이터로...
# > - 라벨링은 라벨링 툴로...
# > - 주피터로 어떻게 한다는데 관심 없음...
# > - 모호한 라벨링은 투표를...
# > - 크라우드 소싱...
# > - 빠르고 전문적이지만 전문분야는 곤란한 라벨링 서비스...
# > ---
# > <b style="color: #53a593">자동 라벨링</b>
# > - 떠드는 학생 모델
# > - 몇개 직접 라벨링 -> 학습 -> 라벨링 모델 -> 자동 라벨링 -> 학생모델 학습 -> 확신도 떨어지는 이미지 보완 -> 반복
# > - 자체 지도 학습
# > - 10장에서 한다는데 뭔소린지...
# > ---
# > <b style="color: #53a593">편향</b>
# > - 선택 편향(데이터 불균형): 데이터 제한--개인정보 등의 이유로 제한되거나 날씨가 좋지 않을때 수집한다거나 기타 등등--, 데이터셋 정리 등으로 인해
# > - 측정 편향: 학습데이터와 운영데이터의 차이로 인해, 수집을 각기 다르게 할때
# > - 홗증 편향: 모르는걸 모르는거... 합격자 서류를 데이터로 쓸때 면접관의 편견이 데이터에 포함되어있다
# > ---
# > <b style="color: #53a593">데이터셋</b>
# > - 분할 8:1:1
# > - TFRecord, TFRecorder: 몰라 쓸때 따로 공부하든가
